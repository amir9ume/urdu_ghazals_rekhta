# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm


base_url = 'https://www.rekhta.org'
poets = []

for letter in tqdm('ABCDEFGHIJKLMNOPQRSTUVWXYZ'):
    url = f'{base_url}/poets?startswith={letter}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    for poet_div in soup.find_all('div', class_='poetColumn'):
        name_div = poet_div.find('div', class_='poetNameDatePlace')
        name_a = name_div.find('a')
        name = name_a.text.strip()
        href = name_a['href']

        location_div = poet_div.find('div', class_='poetPlaceDate')
        location_a = location_div.find('a')
        # location = location_a.text.strip()

        poet = {
            'name': name,
            'href': href,
            'location': location_a
        }
        poets.append(poet)

print(poets)
# Out:
# 100%|██████████| 26/26 [01:10<00:00,  2.70s/it]
# [{'name': 'A G Josh', 'href': 'https://www.rekhta.org/poets/a-g-josh', 'location': <a href="/domicile/pakistan/punjab/other-57/lahore/poets">Lahore</a>}, {'name': 'A. D. Azhar', 'href': 'https://www.rekhta.org/poets/a-d-azhar', 'location': None}, {'name': 'A. Hameed', 'href': 'https://www.rekhta.org/authors/a-hameed', 'location': <a href="/domicile/pakistan/punjab/other-57/lahore/poets">Lahore</a>}, {'name': 'A. Khayyam', 'href': 'https://www.rekhta.org/authors/a-khayyam-1', 'location': <a href="/domicile/pakistan/sindh/other-19/karachi/poets">Karachi</a>}, {'name': 'A. S Bukhari', 'href': 'https://www.rekhta.org/authors/a-s-bukhari', 'location': None}, {'name': 'A.D.Rahi', 'href': 'https://www.rekhta.org/poets/adrahi', 'location': None}, {'name': "A.R Sahil 'Aleeg'", 'href': 'https://www.rekhta.org/poets/ar-sahil-aleeg', 'location': <a href="/domicile/india/uttar-pradesh/na/na/poets">Uttar pradesh</a>}, {'name': 'Aabid Adeeb', 'href': 'https://www.rekhta.org/poets/aabid-adeeb', 'location': <a href="/domicile/india/rajasthan/other-15/udaipur/poets">Udaipur</a>}, {'name': 'Aabid Jafri', 'href': 'https://www.rekhta.org/poets/aabid-jafri', 'location': None}, {'name': 'aabid umar', 'href': 'https://www.rekhta.org/poets/aabid-umar', 'location': <a href="/domicile/pakistan/punjab/other-57/kasur/poets">Kasur</a>}, {'name': 'Aabida Urooj', 'href': 'https://www.rekhta.org/poets/aabida-urooj', 'location': None}, {'name': 'Aabidullah Ghazi', 'href': 'https://www.rekhta.org/poets/aabidullah-ghazi', 'location': <a href="/domicile/usa/illinoi/other-64/chicago/poets">Chicago</a>}, {'name': 'Aadarsh Dubey', 'href': 'https://www.rekhta.org/poets/aadarsh-dubey', 'location': <a href="/domicile/india/madhya-pradesh/other-17/sagar/poets">Sagar</a>}, {'name': 'Aadil Aseer Dehlvi', 'href': 'https://www.rekhta.org/poets/aadil-aseer-dehlvi', 'location': <a href="/domicile/india/other-10/other/delhi/poets">Delhi</a>}, {'name': 'Aadil Farhat', 'href': 'https://www.rekhta.org/poets/aadil-farhat', 'location': <a href="/domicile/india/jammu-and-kashmir/na/na/poets">Jammu and Kashmir</a>}, {'name': 'Aadil Rahi', 'href': 'https://www.rekhta.org/poets/aadil-rahi', 'location': <a href="/domicile/india/maharashtra/other-30/yavatmal/poets">yavatmal</a>}, {'name': 'Aadil Rasheed', 'href': 'https://www.rekhta.org/poets/aadil-rasheed', 'location': <a href="/domicile/india/other-10/other/delhi/poets">Delhi</a>}, {'name': 'Aadil Raza Mansoori', 'href': 'https://www.rekhta.org/poets/aadil-raza-mansoori', 'location': <a href="/domicile/india/rajasthan/other-15/jaipur/poets">Jaipur</a>}, {'name': 'Aafaque Siddiqui', 'href': 'https://www.rekhta.org/poets/aafaque-siddiqui', 'location': <a href="/domicile/pakistan/sindh/other-19/karachi/poets">Karachi</a>}, {'name': 'Aaftab Lakhnvi', 'href': 'https://www.rekhta.org/poets/aaftab-lakhnvi', 'location': None}, {'name': 'Aaftab Muztar', 'href': 'https://www.rekhta.org/authors/aaftab-muztar', 'location': None}, {'name': 'Aaftab Rais Panipati', 'href': 'https://www.rekhta.org/poets/aaftab-rais-panipati', 'location': <a href="/domicile/india/haryana/other-20/panipat/poets">Panipat</a>}, {'name': 'Aaga nisaar', 'href': 'https://www.rekhta.org/poets/aaga-nisaar', 'location': None}, {'name': 'Aagha Akbarabadi', 'href': 'https://www.rekhta.org/poets/aagha-akbarabadi', 'location': None}, {'name': 'Aagha Ashraf', 'href': 'https://www.rekhta.org/authors/aagha-ashraf', 'location': None}, {'name': 'Aagha Babar', 'href': 'https://www.rekhta.org/authors/aagha-babar', 'location': <a href="/domicile/pakistan/sindh/other-19/karachi/poets">Karachi</a>}, {'name': 'Aah Sambhali', 'href': 'https://www.rekhta.org/authors/aah-sambhali', 'location': <a href="/domicile/india/odisha/odisha/sambhalpur/poets">Sambhalpur</a>}, {'name': 'Aajiz Hengan Ghati', 'href': 'https://www.rekhta.org/poets/aajiz-hengan-ghati', 'location': None}, {'name': 'Aajiz Meer Puri', 'href': 'https://www.rekhta.org/authors/aajiz-meer-puri', 'location': None}, {'name': 'Aakif Gha ...

# %%
import pandas as pd

df = pd.DataFrame(poets)
df.to_csv('poets.csv', index=False)

# %%
df
# Out:
#                           name  \
# 0                     A G Josh
# 1                  A. D. Azhar
# 2                    A. Hameed
# 3                   A. Khayyam
# 4                 A. S Bukhari
# ...                        ...
# 1207             Zaheer Dehlvi
# 1208          Zaheer Fatehpuri
# 1209          Zaheer Ghazipuri
# 1210           Zaheer Kashmiri
# 1211  Zaheer Nashad Darbhangwi
#
#                                                    href      location
# 0                 https://www.rekhta.org/poets/a-g-josh      [Lahore]
# 1                https://www.rekhta.org/poets/a-d-azhar          None
# 2               https://www.rekhta.org/authors/a-hameed      [Lahore]
# 3            https://www.rekhta.org/authors/a-khayyam-1     [Karachi]
# 4            https://www.rekhta.org/authors/a-s-bukhari          None
# ...                                                 ...           ...
# 1207         https://www.rekhta.org/poets/zaheer-dehlvi       [Delhi]
# 1208      https://www.rekhta.org/poets/zaheer-fatehpuri          None
# 1209      https://www.rekhta.org/poets/zaheer-ghazipuri  [Hazaribagh]
# 1210       https://www.rekhta.org/poets/zaheer-kashmiri      [Lahore]
# 1211  https://www.rekhta.org/authors/zaheer-nashad-d...   [Darbhanga]
#
# [1212 rows x 3 columns]
